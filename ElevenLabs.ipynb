# %% [markdown]
# <a href="https://colab.research.google.com/github/dhenypatungka/Utilities/blob/main/ElevenLabs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title ## **1. Install ElevenLabs**
# !pip install elevenlabs -U

# %%
from elevenlabs import generate, play
#Pilihan voice: Bella, Antoni, Adam, Arnold, Callum, Charlie, Charlotte, Clyde, Daniel, Dave, Domi, Dorothy, Michael, Liam, Jessie, Elli, Emily, Ethan, Gigi, Giovanni, Thomas, Sam, Serena, Mimi, Glinda, Grace

INPUT_TEXT = "Fear has always been a very important whistleblower. Our emotion and our history can provoke fear that may arrest us at any time or at any place. Above and beyond, fear might be contagious and its scent, sometimes sensual, sometimes mystical or animal, can exude the musty and arcane smell of destiny." #@param {type:"string"}
SUARA = "Emily" # @param ["Bella", "Antoni", "Adam", "Arnold", "Callum", "Charlie", "Charlotte", "Clyde", "Daniel", "Dave" , "Domi" , "Dorothy" , "Michael" , "Liam" , "Jessie" , "Elli", "Emily", "Ethan", "Gigi", "Giovanni", "Thomas", "Sam", "Serena", "Mimi", "Glinda","Grace"] {allow-input: false}
audio = generate (
    text= INPUT_TEXT ,
    voice= SUARA ,
    model= "eleven_multilingual_v2",
)
play(audio, notebook=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
